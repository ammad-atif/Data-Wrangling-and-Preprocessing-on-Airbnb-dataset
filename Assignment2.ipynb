# %% [markdown]
# # Assignment 2: Advanced Data Wrangling and Preprocessing

# %% [markdown]
# ## Instructions
#
# - Submit via Google Classroom before the deadline.
# - Filename format: RollNo_Assignment2.ipynb (e.g., 21L-1234_Assignment2.ipynb)
# - Use Google Colab or Jupyter Notebook.
# - Add comments and explanations for every step.
# - Justify your choice of methods (e.g., median vs mean, Z-score vs IQR).
# - Add assumptions where needed
# - Academic dishonesty = 0 marks + penalties.
# - Viva may be conducted on your code.

# %% [markdown]
# ## Datasets
#
# 1. Airbnb Listings (Global): provivded in gcr
# 2. World Happiness Report (2015-2019): https://www.kaggle.com/datasets/unsdsn/world-happiness (5 CSVs, one per year)

# %% [markdown]
# ## Part A – Data Exploration and Quality Assessment (20 marks)
#
# 1. Load the Airbnb dataset and display top 10 rows, shape, column names, and percentage of missing values (visualize with heatmap).
# 2. Fix at least 3 format inconsistencies (date parsing, currency symbols, text casing).
# 3. Identify and correct mixed data types (numeric + string).
# 4. Drop columns with >40% missing values and justify choice. Impute others suitably.
# 5. For World Happiness dataset, merge all 5 CSVs (2015-2019) into one DataFrame. Add a 'year' column, then compute mean happiness per region per year and visualize annual trends.

# %% [markdown]
# ## Part B – Outlier and Anomaly Detection (15 marks)
#
# 1. Detect outliers in Airbnb 'price', 'service fee' and 'minimum_nights' using both IQR and Z-Score methods.
# 2. Visualize outliers with boxplots and violin plots.
# 3. If ouliers found Remove or cap outliers using a justified approach.

# %% [markdown]
# ## Part C – Data Integration and Transformation (25 marks)
#
# 1. Aggregate Airbnb data by country (avg_price, avg_reviews). Merge with combined Happiness dataset on country.
# 2. Perform inner join and analyze correlation between avg_price and happiness_score.
# 3. Normalize numerical columns using StandardScaler and MinMaxScaler.
# 4. Encode categorical variables (One-Hot for room_type, Label for neighbourhood_group).
# 5. Engineer new features like price_per_night and review_ratio.

# %% [markdown]
# ## Part D – Advanced Data Cleaning Tasks (20 marks)
#
# 1. Detect and remove near-duplicate Airbnb listings using fuzzy matching.
# 2. Clean and convert mixed currency prices to USD.
# 3. plot correlation matrix for airbnb dataset
# 4. Visualize distribution of categorical columns such as 'neighbourhood group' and 'neighborhood'.
# 5. Save cleaned dataset as Cleaned_Airbnb.csv.

# %% [markdown]
# ## Part E – Reflection and Justification (10 marks)
#
# 1. Describe 3 hardest wrangling challenges and how you solved them.
# 2. Discuss which transformations improved data quality most.
# 3. State next preprocessing step before modeling.

# %% [markdown]
# ## Bonus (+5 Marks)
#
# Perform automated EDA using ydata-profiling or sweetviz and visualize at least one key insight.
